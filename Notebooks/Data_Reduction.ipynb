# %% [markdown]
# # Data Reduction

# %% [markdown]
# Reducing the dataset for better performance
#
# 👉 Data type Conversion
#
# converting current npy files whose data type is 😐float64 (64 bits per value) to lower precision data type of 🙂float32 (32 bits per value)

# %%
import numpy as np
import os

# %%
data = np.load('../Data/Split/train/mask/0.npy')

# %%
data.dtype
# Out:
# dtype('float64')

# %% [markdown]
# 👉Defining Paths for train, validation and test data

# %%
train_image = '../Data/Split/train/data/'
train_mask = '../Data/Split/train/mask/'

val_image = '../Data/Split/val/data/'
val_mask = '../Data/Split/val/mask/'

test_image = '../Data/Testing/data/'

# %% [markdown]
#
#
# 👉 for TRAIN IMAGES

# %%
for img in os.listdir(train_image):
    data = np.load(train_image + img)
    if data.dtype == np.float64:
        data = data.astype(np.float32)
    np.save(train_image + img, data)

# %% [markdown]
# 👉 for TRAIN MASKS

# %%
for img in os.listdir(train_mask):
    data = np.load(train_mask + img)
    if data.dtype == np.float64:
        data = data.astype(np.float32)
    np.save(train_mask + img, data)

# %% [markdown]
# 👉 for VALIDATION IMAGES

# %%
data = np.load('../Data/Split/val/data/3.npy')
data.dtype
# Out:
# dtype('float32')

# %%
for img in os.listdir(val_image):
    data = np.load(val_image + img)
    if data.dtype == np.float64:
        data = data.astype(np.float32)
    np.save(val_image + img, data)

# %% [markdown]
# 👉 for VALIDATION MASKS

# %%
data = np.load('../Data/Split/val/mask/3.npy')
data.dtype
# Out:
# dtype('float32')

# %%
for img in os.listdir(val_mask):
    data = np.load(val_mask + img)
    if data.dtype == np.float64:
        data = data.astype(np.float32)
    np.save(val_mask + img, data)

# %% [markdown]
# 👉 for TEST IMAGES

# %%
data = np.load('../Data/Testing/data/v1.npy')
data.dtype
# Out:
# dtype('float32')

# %%
for img in os.listdir(test_image):
    data = np.load(test_image + img)
    if data.dtype == np.float64:
        data = data.astype(np.float32)
    np.save(test_image + img, data)

# %%
for img in os.listdir(train_image):
    data = np.load(train_image + img)
    print(img, data.dtype)
# Out:
# 0.npy float32
# 1.npy float32
# 10.npy float32
# 101.npy float32
# 103.npy float32
# 104.npy float32
# 105.npy float32
# 107.npy float32
# 108.npy float32
# 109.npy float32
# 11.npy float32
# 110.npy float32
# 111.npy float32
# 113.npy float32
# 114.npy float32
# 115.npy float32
# 116.npy float32
# 117.npy float32
# 118.npy float32
# 119.npy float32
# 12.npy float32
# 121.npy float32
# 122.npy float32
# 123.npy float32
# 124.npy float32
# 125.npy float32
# 126.npy float32
# 127.npy float32
# 129.npy float32
# 13.npy float32
# 130.npy float32
# 131.npy float32
# 132.npy float32
# 134.npy float32
# 135.npy float32
# 137.npy float32
# 138.npy float32
# 140.npy float32
# 141.npy float32
# 142.npy float32
# 143.npy float32
# 144.npy float32
# 145.npy float32
# 146.npy float32
# 147.npy float32
# 149.npy float32
# 150.npy float32
# 151.npy float32
# 152.npy float32
# 153.npy float32
# 154.npy float32
# 156.npy float32
# 157.npy float32
# 159.npy float32
# 16.npy float32
# 160.npy float32
# ...

# %%
for img in os.listdir(train_mask):
    data = np.load(train_mask + img)
    print(img, data.dtype)
# Out:
# 0.npy float32
# 1.npy float32
# 10.npy float32
# 100.npy float32
# 101.npy float32
# 103.npy float32
# 104.npy float32
# 105.npy float32
# 107.npy float32
# 108.npy float32
# 109.npy float32
# 11.npy float32
# 110.npy float32
# 111.npy float32
# 113.npy float32
# 114.npy float32
# 115.npy float32
# 116.npy float32
# 117.npy float32
# 118.npy float32
# 119.npy float32
# 12.npy float32
# 121.npy float32
# 122.npy float32
# 123.npy float32
# 124.npy float32
# 125.npy float32
# 126.npy float32
# 127.npy float32
# 129.npy float32
# 13.npy float32
# 130.npy float32
# 131.npy float32
# 132.npy float32
# 134.npy float32
# 135.npy float32
# 137.npy float32
# 138.npy float32
# 140.npy float32
# 141.npy float32
# 142.npy float32
# 143.npy float32
# 144.npy float32
# 145.npy float32
# 146.npy float32
# 147.npy float32
# 149.npy float32
# 150.npy float32
# 151.npy float32
# 152.npy float32
# 153.npy float32
# 154.npy float32
# 156.npy float32
# 157.npy float32
# 159.npy float32
# 16.npy float32
# ...

# %%
for img in os.listdir(val_image):
    data = np.load(val_image + img)
    print(img, data.dtype)
# Out:
# 100.npy float32
# 102.npy float32
# 106.npy float32
# 112.npy float32
# 120.npy float32
# 128.npy float32
# 133.npy float32
# 136.npy float32
# 139.npy float32
# 14.npy float32
# 148.npy float32
# 15.npy float32
# 155.npy float32
# 158.npy float32
# 163.npy float32
# 164.npy float32
# 166.npy float32
# 167.npy float32
# 169.npy float32
# 172.npy float32
# 174.npy float32
# 18.npy float32
# 192.npy float32
# 196.npy float32
# 197.npy float32
# 198.npy float32
# 20.npy float32
# 202.npy float32
# 204.npy float32
# 205.npy float32
# 21.npy float32
# 211.npy float32
# 223.npy float32
# 229.npy float32
# 230.npy float32
# 235.npy float32
# 24.npy float32
# 253.npy float32
# 254.npy float32
# 258.npy float32
# 26.npy float32
# 262.npy float32
# 263.npy float32
# 273.npy float32
# 278.npy float32
# 281.npy float32
# 287.npy float32
# 3.npy float32
# 304.npy float32
# 308.npy float32
# 309.npy float32
# 311.npy float32
# 327.npy float32
# 328.npy float32
# 330.npy float32
# 338.npy float32
# ...

# %%
for img in os.listdir(val_mask):
    data = np.load(val_mask + img)
    print(img, data.dtype)
# Out:
# 100.npy float32
# 102.npy float32
# 106.npy float32
# 112.npy float32
# 120.npy float32
# 128.npy float32
# 133.npy float32
# 136.npy float32
# 139.npy float32
# 14.npy float32
# 148.npy float32
# 15.npy float32
# 155.npy float32
# 158.npy float32
# 163.npy float32
# 164.npy float32
# 166.npy float32
# 167.npy float32
# 169.npy float32
# 172.npy float32
# 174.npy float32
# 18.npy float32
# 192.npy float32
# 196.npy float32
# 197.npy float32
# 198.npy float32
# 20.npy float32
# 202.npy float32
# 204.npy float32
# 205.npy float32
# 21.npy float32
# 211.npy float32
# 223.npy float32
# 229.npy float32
# 230.npy float32
# 235.npy float32
# 24.npy float32
# 253.npy float32
# 254.npy float32
# 258.npy float32
# 26.npy float32
# 262.npy float32
# 263.npy float32
# 273.npy float32
# 278.npy float32
# 281.npy float32
# 287.npy float32
# 3.npy float32
# 304.npy float32
# 308.npy float32
# 309.npy float32
# 311.npy float32
# 327.npy float32
# 328.npy float32
# 330.npy float32
# 338.npy float32
# ...

# %%
for img in os.listdir(test_image):
    data = np.load(test_image + img)
    print(img, data.dtype)
# Out:
# v0.npy float32
# v1.npy float32
# v10.npy float32
# v100.npy float32
# v101.npy float32
# v102.npy float32
# v103.npy float32
# v104.npy float32
# v105.npy float32
# v106.npy float32
# v107.npy float32
# v108.npy float32
# v109.npy float32
# v11.npy float32
# v110.npy float32
# v111.npy float32
# v112.npy float32
# v113.npy float32
# v114.npy float32
# v115.npy float32
# v116.npy float32
# v117.npy float32
# v118.npy float32
# v119.npy float32
# v12.npy float32
# v120.npy float32
# v121.npy float32
# v122.npy float32
# v123.npy float32
# v124.npy float32
# v13.npy float32
# v14.npy float32
# v15.npy float32
# v16.npy float32
# v17.npy float32
# v18.npy float32
# v19.npy float32
# v2.npy float32
# v20.npy float32
# v21.npy float32
# v22.npy float32
# v23.npy float32
# v24.npy float32
# v25.npy float32
# v26.npy float32
# v27.npy float32
# v28.npy float32
# v29.npy float32
# v3.npy float32
# v30.npy float32
# v31.npy float32
# v32.npy float32
# v33.npy float32
# v34.npy float32
# ...
